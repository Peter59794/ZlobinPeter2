# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:
#
# documents = [
#     {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#     {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#     {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
#
# Перечень полок, на которых находятся документы хранится в следующем виде:
#
# directories = {
#     '1': ['2207 876234', '11-2'],
#     '2': ['10006'],
#     '3': []
# }
#
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
#     p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
#     s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
#     Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ.
#     l – list – команда, которая выведет список всех документов в формате
#     passport "2207 876234" "Василий Гупкин"
#     as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. Предусмотрите случай, когда пользователь добавляет полку, которая уже существует.
#     d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
#     m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
#     a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку.

# %%
from pprint import pprint

documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}
     #Я не понимаю, иногда /n Работает иногда нет
dc = 'Введите одну из команд: \n p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит; \n s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится; \n l – list – команда, которая выведет список всех документов в формате passport "2207 876234" "Василий Гупкин" \n as_ – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. \n d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок; \n m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую; \n a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, \n имя владельца и номер полки, на котором он будет храниться.'
print (dc)
print ()
def p():
    n_of_d = input("Введите номер документа ")
    pp = [x['name'] for x in documents if n_of_d == x['number']]
    return print(*pp)

def s():
    n_of_d = input("Введите номер документа ")
    pp = []
    for keys, values in directories.items():
        if n_of_d in values:
            pp.append(keys)
            print (*keys)
        else:
            
            print ('Вы ввели не верный номер документа' )   

            ei = input('Хотите повторить ввод ? да/нет ? ')

            if ei == 'да':
                s()
            elif ei != 'да':
                print ('Перезапустите программу')
                break
        return

def l():
    
    ppp= []
    
    for strr in documents:
        for val in strr.values():
            ppp.append(val)
    
    result = [[]]

    for doc in ppp:
        res_last_el_index = len(result) - 1
        res_last_el = result[res_last_el_index]
    
        if len(res_last_el) == 3:
            new_res_el = [doc]
            result.append(new_res_el)
    
        else:
            res_last_el.append(doc)
    
    for m in result:
        print (*m)
    return

def as_():
    mm = input('Введите номер новой полки ')
        
    if mm not in directories.keys():
        directories[mm] = []
        print (directories)
            
    else:
            
        print ('Полка которую вы пытаетесь создать уже существует')

        ei = input('Хотите повторить ввод ? да/нет ? ')

        if ei == 'да':
            as_()
        elif ei != 'да':
            print ('Перезапустите программу')
    return            
        
def d():
    kk = input('Введите номер документа который вы хотите удалить из каталога и перечня полок ')
    jj= []

    for k, v in directories.items():
        if kk in v:
            jj.append(k)
            print(jj)
        
        else:
        
            print ('Вы ввели не верный номер документа' )
            ei = input('Хотите повторить ввод ? да/нет ? ')
    
        if ei == 'да':
            s()
        elif ei != 'да':
            print ('Перезапустите программу')
        break
    try:            
        del(directories[jj[0]])
        u = int(jj[0])-1
        documents.remove(documents[u])

        print(directories)
        print (documents)
    except:
        return

def m():
    
    v11 = [] #Временный бокс(value) для того, что потом поставиться на место переноса
    v22 = [] #Временный бокс(value) в котором будет подчищенно значение которое переносится
    
    uu = input('Введите номер документа который вы хотите переместить ')
    ss = input('Введите номер полки на которую вы хотите переместить документ ')
    
    for k1, v1 in directories.items():
        if uu in v1:
            v22.append(v1)
    if uu in v22:
        v22.remove(uu)
    directories.update ({k1:v22})
    
    
    for k2, v2 in directories.items():
        if ss in k2:
            v11.append(v2)
            v11.append(uu)
    directories.update({ss:v11})
    
    
    
    print (directories)
    
#     print (v11)
#     print (v22)
               

# directories = {
#     '1': ['2207 876234', '11-2'],
#     '2': ['10006', '11-2'],
#     '3': ['1233']            
# }      

#     print (directories)
            
#     print (directories)          

#         elif print(directories):
#             np = input('Номер котороый вы пытаетесь перенести не существует, \n хотите повторить ввод: да\нет? ')
#             if np == 'да':
#                 m()
#             else:
#                 np != 'да'
#                 print ('Перезапустите программу')


def a():
    
    bb = input('Введите номер полки на которой будет храниться номер ')
    
    if bb not in directories.keys():
        directories[bb] = []
        print (directories)
        print ()
        print ('Введите данные для катлога:')
        print ()
        tt = input('Введите тип ')

        num = input('Введите номер ')

        nam = input('Введите имя ')

        nd = {'type': tt, 'number': num, 'name': nam}

        print () 

        documents.append(nd)
        
        print()
        
        for xx in documents:
            print (*xx.items())
            
    else:
        print ('Полка которую вы пытаетесь создать уже существует')

        np = input('Хотите повторить ввод ? да/нет ? ')

        if np == 'да':
            a()
            
        if np != 'да':
            print ('Перезапустите программу')
    
    
    
    
    return



comand = {'p': p, 's':s, 'l':l, 'as_':as_, 'd':d, 'm':m, 'a':a}

x = input()

comand[x]()
# Out:
# Введите одну из команд:
#  p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
#  s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится;
#  l – list – команда, которая выведет список всех документов в формате passport "2207 876234" "Василий Гупкин"
#  as_ – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень.
#  d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок;
#  m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую;
#  a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип,
#  имя владельца и номер полки, на котором он будет храниться.
#
# l
# passport 2207 876234 Василий Гупкин
# invoice 11-2 Геннадий Покемонов
# insurance 10006 Аристарх Павлов
